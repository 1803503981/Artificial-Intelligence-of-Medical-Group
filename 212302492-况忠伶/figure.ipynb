# %% [markdown]
# # 读取数据

# %%
data = pd.read_csv(r"D:\学习资料\项目资料\耳鸣中医知识图谱\neo4j\数据\新数据\知识图谱新数据.csv",encoding="gbk")
features=data.columns

data
# Out:
#           患者 性别 发病节气  劳累 噪音  耳机使用  锻炼  压力  感染  抽烟  ...   INR  APTT   FIB  \
# 0        患者0  女   大寒   0  0     0   0   0   0   0  ...  0.97  35.3  2.39
# 1        患者1  男   大寒   0  0     0   0   0   0   0  ...  1.03  34.7  2.85
# 2        患者2  男   立春   0  0     0   0   0   0   0  ...  1.13  38.8  2.79
# 3        患者3  女   立春   0  0     0   0   0  感染   0  ...  1.16  23.6  5.66
# 4        患者4  女   大寒  劳累  0     0   0   0   0   0  ...  0.95  25.1  3.17
# ...      ... ..  ...  .. ..   ...  ..  ..  ..  ..  ...   ...   ...   ...
# 1260  患者1260  女    0   0  0  耳机使用   0  压力   0   0  ...   NaN   NaN   NaN
# 1261  患者1261  女    0   0  0  耳机使用  锻炼  压力   0   0  ...   NaN   NaN   NaN
# 1262  患者1262  女    0   0  0     0   0  压力   0   0  ...   NaN   NaN   NaN
# 1263  患者1263  女    0   0  0     0   0  压力   0   0  ...   NaN   NaN   NaN
# 1264  患者1264  男    0   0  0     0  锻炼   0   0  抽烟  ...   NaN   NaN   NaN
#
#      D-二聚体    TT    年龄  病程（月） TEQ THI  VAS
# 0     0.19  18.3  45.0    7.0  10  18  6.0
# ...

# %%
data["年龄"].unique()
# Out:
# array([45., 75., 74., 72., 50., 64., 17., 30., 80., 66., 36., 35., 22.,
#        41., 63., 26., 29., 71., 40., 52., 49., 46., 31., 59., 53., 56.,
#        38., 48., 42., 44., 34., 67., 39., 61., 27., 54., 68., 62., 43.,
#        47., 69., 65., 70., 58., 37., 57., 33., 76., 79., 32., 55., 77.,
#        24., 51., 28., 78., 25., 60., 73., 21.,  8., 88., 85., 20., 23.,
#        84., 82., 18., 83., 86., 19., nan, 12., 10.,  4.])

# %%
tips["Syndrome"]
# Out:
# 0       肾精亏虚
# 1       肾精亏虚
# 2       肾精亏虚
# 3       痰火郁结
# 4       脾胃虚弱
#         ...
# 1260    痰火郁结
# 1261    风热侵袭
# 1262    肝火上扰
# 1263    脾胃虚弱
# 1264    脾胃虚弱
# Name: syndrome, Length: 1265, dtype: object

# %% [markdown]
# # 英文数据

# %%
tips = pd.read_csv(r"D:\学习资料\项目资料\耳鸣中医知识图谱\neo4j\数据\新数据\英文版\知识图谱新数据_编辑修改版.csv",encoding="gbk")
tips
# Out:
#           Patient     Sex SolarTermOfOnset  fatigue noise  use headphones  \
# 0        Patient0  Female       Great cold        0     0               0
# 1        Patient1    Male       Great cold        0     0               0
# 2        Patient2    Male    Spring begins        0     0               0
# 3        Patient3  Female    Spring begins        0     0               0
# 4        Patient4  Female       Great cold  fatigue     0               0
# ...           ...     ...              ...      ...   ...             ...
# 1260  Patient1260  Female                0        0     0  use headphones
# 1261  Patient1261  Female                0        0     0  use headphones
# 1262  Patient1262  Female                0        0     0               0
# 1263  Patient1263  Female                0        0     0               0
# 1264  Patient1264    Male                0        0     0               0
#
#       exercise  pressure  infection  smoke  ...   INR  APTT   FIB D-dimer  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
#设置绘图风格
plt.style.use('seaborn-whitegrid')#ggplot、seaborn-white、seaborn-whitegrid
#处理中文乱码
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
#坐标轴负号的处理
plt.rcParams['axes.unicode_minus']=False
# 读取数据
tips = pd.read_csv(r"D:\学习资料\项目资料\耳鸣中医知识图谱\neo4j\原始数据\新数据\英文版\知识图谱新数据英文.csv",encoding="gbk")

featrue=tips["Syndrome"].unique()
# tips["Syndrome"].unique()
# 绘制分组小提琴图
for item in items:
    sns.violinplot(x = "Age", # 指定x轴的数据
                   y = "Syndrome", # 指定y轴的数据
                   hue = "Sex", # 指定分组变量
                   data = tips, # 指定绘图的数据集
                   order = tips["Syndrome"].unique(), # 指定x轴刻度标签的顺序
                   showmeans=True,#显示均值
                   scale = 'count', # 以男女客户数调节小提琴图左右的宽度
                   split = True, # 将小提琴图从中间割裂开，形成不同的密度曲线；
                   style="ticks",
                   palette = 'deep' # 指定不同性别对应的颜色（因为hue参数为设置为性别变量）RdBu
                   ,orient='h'#横向
                  )
# 添加图形标题
# plt.title('The Age distribution of different gender patients in each Syndrome type')
# 设置图例
# plt.legend(loc = 'upper right', ncol = 2)
#控制横纵坐标的值域
plt.axis([0,100,-1,6])
# 显示图形
# plt.savefig(f"./outData新数据/图片/证型-年龄-性别.png", dpi=600,format="png",bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,8))
#设置绘图风格
plt.style.use('classic')#ggplot、seaborn-white、classic、seaborn-whitegrid
#处理中文乱码
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
#坐标轴负号的处理
plt.rcParams['axes.unicode_minus']=False
tips = pd.read_csv(r"D:\学习资料\项目资料\耳鸣中医知识图谱\neo4j\原始数据\新数据\英文版\知识图谱新数据英文.csv",encoding="gbk")
sns.violinplot(x="Age", y="Syndrome", hue="Sex",data=tips,bw=0.2,orient='h',
               order = tips["Syndrome"].unique(), # 指定x轴刻度标签的顺序
               showmeans=True,#显示均值
               scale = 'count', # 以男女客户数调节小提琴图左右的宽度
               split = True, # 将小提琴图从中间割裂开，形成不同的密度曲线；
               style="ticks",
               size=4, aspect=.75,)
plt.axis([0,100,-1,6])
# plt.savefig(f"./outData新数据/图片/证型-年龄-性别.png", dpi=300,format="png",bbox_inches='tight')
# Out:
# (0.0, 100.0, -1.0, 6.0)

# %%
fig = go.Figure()

syns = ['肾精亏虚', '痰火郁结', '脾胃虚弱', '肝火上扰', '风热侵袭']

for syn in syns:
    fig.add_trace(go.Violin(x=data['中医辨证'][data['中医辨证'] == syn],
                            y=data['年龄'][data['中医辨证'] == syn],
                            name=syn,
                            box_visible=True,
                            meanline_visible=True))

fig.show()

# %% [markdown]
# # 证型

# %%
import plotly.graph_objects as go

import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/violin_data.csv")

fig = go.Figure()

fig.add_trace(go.Violin(x=df['day'][ df['smoker'] == 'Yes' ],
                        y=df['total_bill'][ df['smoker'] == 'Yes' ],
                        legendgroup='Yes', scalegroup='Yes', name='Yes',
                        side='negative',
                        line_color='blue')
             )
fig.add_trace(go.Violin(x=df['day'][ df['smoker'] == 'No' ],
                        y=df['total_bill'][ df['smoker'] == 'No' ],
                        legendgroup='No', scalegroup='No', name='No',
                        side='positive',
                        line_color='orange')
             )
fig.update_traces(meanline_visible=True)
fig.update_layout(violingap=0, violinmode='overlay')
fig.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['WenQuanYi Zen Hei']  # 设置中文显示为宋体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示为方块的问题

# %%
fig = go.Figure()

fig.update_layout(
    font_size=18,
    font_family='WenQuanYi Zen Hei',
    paper_bgcolor='white',
    plot_bgcolor='white',
    height=400,
    width=800,
    legend_bordercolor="black",
    legend_itemsizing="trace",
    margin=dict(t=100,pad=10),
    yaxis=dict(
        title='Syndrome',
        title_font_color='black',
        gridcolor='#BEBEBE',
    ),
    xaxis=dict(
        title='Age',
        title_font_color='black',
        gridcolor='#BEBEBE',
    ),
    legend=dict(
        font=dict(
            family='WenQuanYi Zen Hei',
            size=20,
            color='black'
        )
    ),
    violingap=0
)

fig.add_trace(go.Violin(x=tips['Age'][ tips['Sex'] == 'Female'],
                        y=tips['Syndrome'][ tips['Sex'] == 'Female' ],
                        legendgroup='Female', scalegroup='Female', name='Female',
                        side='positive',
                        line_color='#FF5678')
             )
fig.add_trace(go.Violin(x=tips['Age'][ tips['Sex'] == 'Male' ],
                        y=tips['Syndrome'][ tips['Sex'] == 'Male' ],
                        legendgroup='Male', scalegroup='Male', name='Male',
                        side='negative',
                        line_color='#57E3F2')
             )
fig.update_traces(orientation='h',  width=3, points=False)

fig.update_traces(meanline_visible=True)
fig.update_layout(violingap=0, violinmode='overlay')
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = 'notebook'
fig.write_image("figure.png", width=800, height=400)

# %% [markdown]
# # 舌

# %%
import kaleido

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()
fig.update_layout(
    font_size=18,
    font_family='WenQuanYi Zen Hei',
    legend=dict(
        font=dict(
            family='WenQuanYi Zen Hei',
            size=20,
            color='black'
        )
    ),
    paper_bgcolor='white',
    plot_bgcolor='white',
    height=400,
    width=800,
    margin=dict(t=100,pad=10),
    yaxis=dict(
        title='Syndrome',
        title_font_color='black',
        gridcolor='#BEBEBE',
    ),
    xaxis=dict(
        title='Tongue body',
        title_font_color='black',
    ),
)
# fig.add_annotation(
#     x=0,y=7,
#     text='我是注释',
#     font=dict(color='red')
# )
tips = pd.read_csv(r"D:\学习资料\项目资料\耳鸣中医知识图谱\neo4j\数据\新数据\英文版\知识图谱新数据_编辑修改版.csv",encoding="gbk")
features=tips.columns
items=features[71:74]#舌
# items=['reddish tongue','light color of tongue','dark tongue']
colors=['#204473','#204473','#204473']
fillcolor=['#7E8C69','#ACCAF2','#0897B4']
i=0
for item in items:
    print(item)
    fig.add_trace(go.Violin(x=tips[f'{item}'][tips[f'{item}']!='0'],
                            y=tips['Syndrome'][tips[f'{item}'] == item],
                            name=item,
                            box_visible=True,
                            meanline_visible=True,fillcolor=fillcolor[i],line_color=colors[i]
                           ))
    i=i+1
fig.show()
# Out:
# Reddish tongue
# Light color of tongue
# Dark tongue

# %%
import plotly.io as pio
pio.renderers.default = 'notebook'
fig.write_image("figure1.png", width=800, height=400)

# %% [markdown]
# # 苔

# %%
features[74:79]
# Out:
# Index(['Thin fur', 'Greasy moss', 'White fur', 'Moss yellow',
#        'Moss deficiency'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import kaleido

fig = go.Figure()
fig.update_layout(
    font_size=18,
    font_family='WenQuanYi Zen Hei',
    legend=dict(
        font=dict(
            family='WenQuanYi Zen Hei',
            size=20,
            color='black'
        )
    ),
    paper_bgcolor='white',
    plot_bgcolor='white',
    height=400,
    width=800,
    margin=dict(t=100,pad=10),
    yaxis=dict(
        title='Syndrome',
        title_font_color='black',
        gridcolor='#BEBEBE',
    ),
    xaxis=dict(
        title='Tongue fur',
        title_font_color='black',
    ),
)
tips = pd.read_csv(r"D:\学习资料\项目资料\耳鸣中医知识图谱\neo4j\数据\新数据\英文版\知识图谱新数据_编辑修改版.csv",encoding="gbk")
features=tips.columns
items=features[74:79]#舌
# items=['Thin fur', 'Greasy moss', 'White fur', 'Moss yellow', 'Moss deficiency']
colors=['#646C8F','#646C8F','#646C8F','#646C8F','#646C8F']#8F797E
fillcolor=['#FC8DCA','#C37EDB','#B7A6F6','#88A3E2','#AAECFC']
i=0
for item in items:
    print(item)
    fig.add_trace(go.Violin(x=tips[f'{item}'][tips[f'{item}']!='0'],
                            y=tips['Syndrome'][tips[f'{item}'] == item],
                            name=item,
                            box_visible=True,
                            meanline_visible=True,fillcolor=fillcolor[i],line_color=colors[i]
                           ))
    i=i+1
fig.show()
# Out:
# Thin fur
# Slimy fur
# White fur
# Yellow fur
# Scanty fur

# %% [markdown]
# # 脉

# %%
features[79:87]
# Out:
# Index(['Floating pulse', 'Deep pulse', 'Rapid pulse', 'String-like pulse',
#        'Slippery pulse', 'Fine pulse', 'Weak pulse', 'Rough pulse'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import kaleido

fig = go.Figure()
fig.update_layout(
    font_size=18,
    font_family='WenQuanYi Zen Hei',
    legend=dict(
        font=dict(
            family='WenQuanYi Zen Hei',
            size=20,
            color='black'
        )
    ),
    paper_bgcolor='white',
    plot_bgcolor='white',
    height=500,
    width=800,
    margin=dict(t=100,pad=10),
    yaxis=dict(
        title='Syndrome',
        title_font_color='black',
        gridcolor='#BEBEBE',
    ),
    xaxis=dict(
        title='Pulse condition',
        title_font_color='black',
    ),
)
tips = pd.read_csv(r"D:\学习资料\项目资料\耳鸣中医知识图谱\neo4j\数据\新数据\英文版\知识图谱新数据_编辑修改版.csv",encoding="gbk")
features=tips.columns
# items=features[79:87]
items=['Floating pulse', 'Deep pulse', 'Rapid pulse', 'String-like pulse','Slippery pulse', 'Fine pulse', 'Weak pulse', 'Rough pulse']
colors=['#8F797E','#8F797E','#8F797E','#8F797E','#8F797E','#8F797E','#8F797E','#8F797E']#8F797E
fillcolor=['#FFBBB3','#E8A2AB','#FFC0E7','#E4A2E8','#E5B3FF','#BDE4FF','#AEA1F0','#B484D9']
i=0
for item in items:
    print(item)
    fig.add_trace(go.Violin(x=tips[f'{item}'][tips[f'{item}']!='0'],
                            y=tips['Syndrome'][tips[f'{item}'] == item],
                            name=item,
                            box_visible=True,meanline_visible=True,
                            fillcolor=fillcolor[i],line_color=colors[i]
                           ))
    i=i+1
fig.show()

# fig.write_image("contour2.png")
# Out:
# Floating pulse
# Deep pulse
# Rapid pulse
# String-like pulse
# Slippery pulse
# Fine pulse
# Weak pulse
# Rough pulse

# %% [markdown]
# # 混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
df=pd.DataFrame(columns=["测试集证型","出现次数最多证型"])
list1=np.zeros((5, 5))
for item in range(0,5):
    knowledge_graph_data=pd.read_csv(f"./outData新数据/图结果/5折_{item}分类结果.csv",encoding="gbk")
    df = pd.concat([df, knowledge_graph_data],ignore_index=True)
    # y_test=knowledge_graph_data["Patient1中医辨证"]
    # y_pre_test=knowledge_graph_data["前20出现次数最多"]
    y_test=knowledge_graph_data["测试集证型"]
    y_pre_test=knowledge_graph_data["出现次数最多证型"]
    # CI=confidenceInterval(y_test,y_score,CIname) #0肾精亏损1肝火上扰2痰火郁结3脾胃亏虚4风热侵袭
    confusion = confusion_matrix(y_test,y_pre_test,labels=[0,1,2,3,4])
    list1=np.sum([list1,confusion],axis=0)
    print(confusion)

# df.to_csv(f"./outData新数据/图结果/总分类结果.csv")
# Out:
# [[77  0  0  1  0]
#  [ 0 62  0  0  0]
#  [ 0  1 28  0  0]
#  [ 1  0  1 59  0]
#  [ 0  0  0  0 23]]
# [[66  0  0  0  0]
#  [ 1 63  0  0  0]
#  [ 0  2 42  0  0]
#  [ 0  0  0 50  0]
#  [ 1  0  0  0 28]]
# [[79  0  0  0  0]
#  [ 1 61  0  0  0]
#  [ 0  0 35  0  0]
#  [ 0  0  0 48  0]
#  [ 0  0  0  0 29]]
# [[53  0  0  2  0]
#  [ 0 57  0  0  0]
#  [ 1  1 45  0  0]
#  [ 1  0  0 54  0]
#  [ 0  0  0  0 39]]
# [[61  0  0  0  0]
#  [ 1 61  0  0  0]
#  [ 0  0 39  0  0]
#  [ 3  0  0 53  0]
#  [ 0  0  0  1 34]]

# %% [markdown]
# ## 输出混淆矩阵

# %%
i=4
df=pd.read_csv(f"./outData新数据/图结果/5折_{i}分类结果.csv",encoding="gbk")
df['测试集证型']= df['测试集证型'].astype('int64')
df['出现次数最多证型']= df['出现次数最多证型'].astype('int64')
y_test=df["测试集证型"]
y_pre_test=df["出现次数最多证型"]
classes=[0,1,2,3,4]
getConfusion(y_test,y_pre_test,[0,1,2,3,4],i)

# %%
#图片显示中文
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] =False #减号unicode编码
# 设置画板尺寸
plt.subplots(figsize = (8,6))
C=confusion_matrix(y_test,y_pre_test,labels=classes)
df=pd.DataFrame(C,index=["KED", "LFBU", "PFSI","QDSS","WFAI"],columns=["KED", "LFBU", "PFSI","QDSS","WFAI"])
ax = sns.heatmap(df,annot_kws={"fontsize":16},annot=True,fmt='1.100g',cmap=sns.cubehelix_palette(as_cmap=True),linewidths=0.1,linecolor="white")#cmap=plt.cm.Reds,sns.cubehelix_palette(as_cmap=True),Greens
#添加图例
ax.set_xlabel('predict',fontsize=20) #x轴
ax.set_ylabel('true',fontsize=20) #y轴
plt.xticks(fontsize=18,color="#363432")#,rotation=30倾斜
plt.yticks(fontsize=18,color="#363432")
plt.show()

# %%
#输出混淆矩阵
from sklearn.metrics import confusion_matrix

def getConfusion(y_test,y_pre_test,classes,i):
    #图片显示中文
    plt.rcParams['font.sans-serif']=['SimHei']
    plt.rcParams['axes.unicode_minus'] =False #减号unicode编码
    # 设置画板尺寸
    plt.subplots(figsize = (8,6))
    C=confusion_matrix(y_test,y_pre_test,labels=classes)
    df=pd.DataFrame(C,index=["KED", "LFBU", "PFSI","QDSS","WFAI"],columns=["KED", "LFBU", "PFSI","QDSS","WFAI"])
    ax = sns.heatmap(df,annot_kws={"fontsize":16},annot=True,fmt='1.100g',cmap=sns.cubehelix_palette(as_cmap=True),linewidths=0.1,linecolor="white")#cmap=plt.cm.Reds,sns.cubehelix_palette(as_cmap=True),Greens
    #添加图例
    ax.set_xlabel('predict',fontsize=20) #x轴
    ax.set_ylabel('true',fontsize=20) #y轴
    plt.xticks(fontsize=18,color="#363432")#,rotation=30倾斜
    plt.yticks(fontsize=18,color="#363432")
    # plt.title("XGBboost混淆矩阵",fontsize=12)#"PKED","PLFDU","PSBPF","PSSD","PWHAE"
    # plt.text(6.5, 0.5, "0: pattern of kidney yin deficiency and fire effulgence",fontsize=12, color = "#4B4952",style = "italic")
    # plt.text(6.5, 1, "1: pattern of liver fire disturbing upward",fontsize=12, color = "#4B4952",style = "italic")
    # plt.text(6.5, 1.5, "2: pattern of stagnation and binding of phlegm and fire",fontsize=12, color = "#4B4952",style = "italic")
    # plt.text(6.5, 2, "3: pattern of spleen and stomach deficiency",fontsize=12, color = "#4B4952",style = "italic")
    # plt.text(6.5, 2.5, "4: pattern of wind and heat attacking the external",fontsize=12, color = "#4B4952",style = "italic")
    plt.savefig(f"./outData新数据/图片/混淆矩阵{i}.png", dpi=600,format="png",bbox_inches='tight')
    plt.show()

# %%
classes=[0,1,2,3,4]
C=confusion_matrix(y_test,y_pre_test,labels=classes)

plot_confusion_matrix(C, classes=classes, normalize=True, title='Normalized confusion matrix')
# Out:
# 显示百分比：
# [[ 0.99  0.00  0.00  0.01  0.00]
#  [ 0.01  0.99  0.00  0.00  0.00]
#  [ 0.01  0.02  0.97  0.00  0.00]
#  [ 0.02  0.00  0.00  0.98  0.00]
#  [ 0.01  0.00  0.00  0.01  0.99]]

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
# 绘制混淆矩阵
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    - cm : 计算出的混淆矩阵的值
    - classes : 混淆矩阵中每一行每一列对应的列
    - normalize : True:显示百分比, False:显示个数
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("显示百分比：")
        np.set_printoptions(formatter={'float': '{: 0.2f}'.format})
        print(cm)
    else:
        print('显示具体数字：')
        print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    # matplotlib版本问题，如果不加下面这行代码，则绘制的混淆矩阵上下只能显示一半，有的版本的matplotlib不需要下面的代码，分别试一下即可
    plt.ylim(len(classes) - 0.5, -0.5)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# # 权重图

# %% [markdown]
# ## 读取权重

# %%
relation_data = pd.read_csv(r"D:\学习资料\项目资料\耳鸣中医知识图谱\neo4j\数据\新数据\关系权重新.csv",encoding="gbk")
relation_data_features=relation_data.columns

relation_data
# Out:
#     肾精亏虚  肾精亏虚特征占比 肝火上扰  肝火上扰特征占比 痰火郁结  痰火郁结特征占比 风热侵袭  风热侵袭特征占比 脾胃虚弱  脾胃虚弱特征占比
# 0     冬至  0.093750   冬至  0.085516   冬至  0.084156   冬至  0.085453   冬至  0.108631
# 1     处暑  0.108500   夏至  0.088773   处暑  0.109929   处暑  0.091904   处暑  0.097520
# 2     夏至  0.096700   大雪  0.082258   夏至  0.094465   夏至  0.085453   夏至  0.090112
# 3     大寒  0.090800   寒露  0.108317   大暑  0.104774   大寒  0.085453   大寒  0.108631
# 4     大暑  0.093750   小寒  0.085516   大雪  0.084156   大暑  0.117711   大暑  0.097520
# ..   ...       ...  ...       ...  ...       ...  ...       ...  ...       ...
# 103   细脉  1.144797  NaN       NaN  NaN       NaN  NaN       NaN   弦脉  0.268139
# 104   弱脉  0.210593  NaN       NaN  NaN       NaN  NaN       NaN   滑脉  0.350392
# 105   涩脉  0.149450  NaN       NaN  NaN       NaN  NaN       NaN   细脉  1.078163
# 106  NaN       NaN  NaN       NaN  NaN       NaN  NaN       NaN   弱脉  0.273392
# 107  NaN       NaN  NaN       NaN  NaN       NaN  NaN       NaN   涩脉  0.158070
#
# [108 rows x 10 columns]

# %%
relation_data = relation_data.sort_values(by="肾精亏虚特征占比",ascending=False)
relation_data
# Out:
#      肾精亏虚  肾精亏虚特征占比  肝火上扰  肝火上扰特征占比  痰火郁结  痰火郁结特征占比  风热侵袭  风热侵袭特征占比  脾胃虚弱  \
# 80     遗精  1.435015  虚烦失眠  0.484652  夜间加重  0.475705  晨起早醒  0.475615    遗精
# 79     腰酸  1.421341  晨起早醒  0.485765  急躁易怒  0.433264  眠浅易醒  0.193138    腰酸
# 90     多梦  1.410441    苔少  0.204622    舌淡  0.364107    苔黄  0.508235    多梦
# 88   晨起早醒  1.386758    苔白  0.161736  烦躁失眠  0.399081    苔腻  0.192530  晨起早醒
# 89   虚烦失眠  1.385645    苔黄  0.911849    舌红  0.644006    苔白  0.292450  虚烦失眠
# ..    ...       ...   ...       ...   ...       ...   ...       ...   ...
# 48    电流声  0.008850   低中频  0.287924    潮声  0.398351    双侧  0.325801   电流声
# 74     胸闷  0.002950  夜间加重  0.459805    口干  0.451908  夜间加重  0.341784    胸闷
# 44    鸣笛声  0.002950   声低沉  0.262413   搏动声  0.005155    潮声  0.372778   鸣笛声
# 106     0  0.000000     0  0.000000     0  0.000000     0  0.000000    弱脉
# 107     0  0.000000     0  0.000000     0  0.000000     0  0.000000    涩脉
#
#      脾胃虚弱特征占比
# 80   0.480017
# 79   0.466343
# 90   0.486514
# 88   0.462831
# ...

# %%
relation_data.isnull()["肾精亏虚"][relation_data.isnull()["肾精亏虚"]==True].index
# Out:
# Int64Index([106, 107], dtype='int64')

# %%
relation_data['肾精亏虚'][relation_data['肾精亏虚']!=0]
# Out:
# 0      冬至
# 1      处暑
# 2      夏至
# 3      大寒
# 4      大暑
#        ..
# 101    数脉
# 102    弦脉
# 103    细脉
# 104    弱脉
# 105    涩脉
# Name: 肾精亏虚, Length: 106, dtype: object

# %% [markdown]
# ## 输出直方图

# %%
for item in relation_data_features:
    NaN_array = relation_data.isnull()[f'{item}'][relation_data.isnull()[f'{item}']==True].index
    for i in NaN_array:
        relation_data[f'{item}'][i]=0
relation_data
# Out:
#     肾精亏虚  肾精亏虚特征占比 肝火上扰  肝火上扰特征占比 痰火郁结  痰火郁结特征占比 风热侵袭  风热侵袭特征占比 脾胃虚弱  脾胃虚弱特征占比
# 0     冬至  0.093750   冬至  0.085516   冬至  0.084156   冬至  0.085453   冬至  0.108631
# 1     处暑  0.108500   夏至  0.088773   处暑  0.109929   处暑  0.091904   处暑  0.097520
# 2     夏至  0.096700   大雪  0.082258   夏至  0.094465   夏至  0.085453   夏至  0.090112
# 3     大寒  0.090800   寒露  0.108317   大暑  0.104774   大寒  0.085453   大寒  0.108631
# 4     大暑  0.093750   小寒  0.085516   大雪  0.084156   大暑  0.117711   大暑  0.097520
# ..   ...       ...  ...       ...  ...       ...  ...       ...  ...       ...
# 103   细脉  1.144797    0  0.000000    0  0.000000    0  0.000000   弦脉  0.268139
# 104   弱脉  0.210593    0  0.000000    0  0.000000    0  0.000000   滑脉  0.350392
# 105   涩脉  0.149450    0  0.000000    0  0.000000    0  0.000000   细脉  1.078163
# 106    0  0.000000    0  0.000000    0  0.000000    0  0.000000   弱脉  0.273392
# 107    0  0.000000    0  0.000000    0  0.000000    0  0.000000   涩脉  0.158070
#
# [108 rows x 10 columns]

# %%
import plotly.figure_factory as ff

importance = [*zip(relation_data["肾精亏虚"], relation_data["肾精亏虚特征占比"])]
importance = pd.DataFrame(importance,columns=["肾精亏虚","肾精亏虚特征占比"])
importance = importance.sort_values(by="肾精亏虚特征占比",ascending=False)  # by指定按哪列排序。ascending表示是否升序
# colorscale = [[0, '#aaaaaa'],[.5, '#ffffff'],[1, '#ffffff']]  # 表格中设置3种颜色
# importance_table = ff.create_table(importance,index=True,index_title='特征序号', colorscale=colorscale)
# importance_table.show()

# %%
importance=importance.head(20)
importance
# Out:
#      肾精亏虚  肾精亏虚特征占比
# 0      遗精  1.435015
# 1      腰酸  1.421341
# 2      多梦  1.410441
# 3    晨起早醒  1.386758
# 4    虚烦失眠  1.385645
# 5    夜间加重  1.167020
# 6     蝉鸣声  1.155862
# 7      细脉  1.144797
# 8      苔少  0.714207
# 9      持续  0.699115
# 10     焦虑  0.681788
# 11   听力下降  0.634218
# 12     舌红  0.543817
# 13     苔薄  0.518264
# 14   烦躁失眠  0.498068
# 15   急躁易怒  0.488718
# 16     双侧  0.455100
# 17     弦脉  0.448506
# 18   入睡困难  0.442478
# 19  耳内空虚感  0.417463

# %%
# 绘图
from matplotlib import pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示中文黑体
# plt.rcParams['axes.unicode_minus'] = False # 负值显示
# relation_data = relation_data.astype(int)

plt.barh(importance['肾精亏虚'], importance['肾精亏虚特征占比'], height=0.7, color='#008792', edgecolor='#005344') # 更多颜色可参见颜色大全
plt.xlabel('feature importance') # x 轴
plt.ylabel('features') # y轴
plt.title('Feature Importances') # 标题

plt.show()

# %% [markdown]
# # ROC
